# %% [markdown]
# <a href="https://colab.research.google.com/github/heona1231/SWAI_2023/blob/dev/0927.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Pandas 라이브러리 활용
#   - 외부데이터, 공공데이터 가져오기

# %%
import pandas as pd

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-d1a01b70-59bb-452c-a048-aae4b861e32b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1a01b70-59bb-452c-a048-aae4b861e32b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('test.xlsx') #엑셀 파일 읽어오기
df
# Out:
#    ID  국어   영어  수학
# 0   1  80   85  75
# 1   2  90  100  95
# 2   3  75   70  65

# %%
food = pd.read_csv('food.csv')
food.head()
food.tail(3)
# Out:
#      Series_reference   Period  Data_value   STATUS  UNITS  \
# 3161   CPIM.SE9S01502  2019.01        1046  REVISED  Index
# 3162   CPIM.SE9S01502  2019.02        1050  REVISED  Index
# 3163   CPIM.SE9S01502  2019.03        1052    FINAL  Index
#
#                           Subject  \
# 3161  Consumers Price Index - CPI
# 3162  Consumers Price Index - CPI
# 3163  Consumers Price Index - CPI
#
#                                                   Group       Series_title_1
# 3161  Food Price Index Level 3 Classes for New Zeala...  Seasonally adjusted
# 3162  Food Price Index Level 3 Classes for New Zeala...  Seasonally adjusted
# 3163  Food Price Index Level 3 Classes for New Zeala...  Seasonally adjusted

# %%
kid = pd.read_csv('kid_20181231.csv', encoding = '949')
kid
# Out:
#      시도   시군구  발생건수  사망자수  부상자수  중상  경상  부상신고
# 0    서울   종로구    28     0    33   1  27     5
# 1    서울    중구    23     0    25   1  16     8
# 2    서울   용산구    34     0    39   6  25     8
# 3    서울   성동구    28     0    31   4  20     7
# 4    서울  동대문구    42     0    46   3  33    10
# ..   ..   ...   ...   ...   ...  ..  ..   ...
# 223  울산    남구    43     0    49   9  36     4
# 224  울산    동구    21     0    21   6  15     0
# 225  울산    북구    29     0    30   6  24     0
# 226  울산   울주군    35     0    51  11  29    11
# 227  세종    세종    49     0    61  18  39     4
#
# [228 rows x 8 columns]

# %%
apart = pd.read_csv('apart_20230630.csv', encoding = '949')
apart.head()
# Out:
#   지역명                     규모구분    연도   월 분양가격(제곱미터)
# 0  서울                     모든면적  2015  10       5841
# 1  서울            전용면적 60제곱미터이하  2015  10       5652
# 2  서울   전용면적 60제곱미터초과 85제곱미터이하  2015  10       5882
# 3  서울  전용면적 85제곱미터초과 102제곱미터이하  2015  10       5721
# 4  서울           전용면적 102제곱미터초과  2015  10       5879
